# %% [markdown]
# ## **Exploración de los datos**

# %%
# Implementación de las librerias utilizadas.
from IPython.display import display # Para mostrar múltiples resultados en una sola celda.
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Variable con la ruta parcial.
ruta = "/content/drive/MyDrive/BEDU/Proyecto/"
# Variable con el nombre del archivo
archivo = "Módulo-de-Fosas-Comunes_actualizacion26abr2024_VD.csv"

# %%
df = pd.read_csv(ruta + archivo)
df.head(5)
# Out:
#         ID      Nombre_completo     Estado_origen Municipio_origen  \
# 0  XX-P001                       Ciudad de México   Miguel Hidalgo
# 1  XX-P002                       Ciudad de México   Miguel Hidalgo
# 2  XX-P003  Alberto Cruz Lucero  Ciudad de México   Miguel Hidalgo
# 3  XX-P004                       Ciudad de México   Miguel Hidalgo
# 4  XX-P005                       Ciudad de México   Miguel Hidalgo
#
#              Panteón_origen  Estatus_FC Fecha_inhumación Fecha_defunción  \
# 0  Panteón Civil de Dolores  Inhumación       30/01/2019      04/03/2018
# 1  Panteón Civil de Dolores  Inhumación       26/01/2019      12/12/2018
# 2  Panteón Civil de Dolores  Inhumación       26/01/2019      13/12/2018
# 3  Panteón Civil de Dolores  Inhumación       26/01/2019      14/12/2018
# 4  Panteón Civil de Dolores  Inhumación       26/01/2019      18/12/2018
#
#        Restos_tipo       Sexo Edad Conocido_Desconocido Nombre(s)  \
# 0  Restos cremados  Masculino   55          Desconocido       NaN
# 1          Cadáver  Masculino  NaN          Desconocido       NaN
# 2          Cadáver  Masculino  NaN             Conocido   Alberto
# 3          Cadáver  Masculino  NaN          Desconocido       NaN
# 4          Cadáver  Masculino  NaN          Desconocido       NaN
#
#   Primer_apellido Segundo_apellido  \
# 0             NaN              NaN
# 1             NaN              NaN
# 2            Cruz           Lucero
# 3             NaN              NaN
# 4             NaN              NaN
#
#                                   Institución_origen Rdoc  Datos alternativos  \
# 0        UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA   Sí                 NaN
# 1  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí                 NaN
# 2  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí                 NaN
# 3  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí                 NaN
# 4  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...   Sí                 NaN
#
#   Marca_temporal
# 0     23/03/2020
# 1     23/03/2020
# 2     23/03/2020
# 3     23/03/2020
# 4     23/03/2020

# %%
# Obtenemos un panorama general de los datos.
def info_general_df(df):
  print('Información general del DataFrame\n')
  print(f'Cantidad de filas y columnas: {df.shape}')
  print("*"*50)
  print(f'Cantidad de datos nulos por columna: \n{df.isnull().sum()}')
  print("*"*50)
  print(f'Tipos de datos por columna: \n{df.dtypes}')

info_general_df(df)
# Out:
# Información general del DataFrame
#
# Cantidad de filas y columnas: (41372, 19)
# **************************************************
# Cantidad de datos nulos por columna:
# ID                          0
# Nombre_completo          2286
# Estado_origen               0
# Municipio_origen            0
# Panteón_origen              0
# Estatus_FC                  0
# Fecha_inhumación            0
# Fecha_defunción         23595
# Restos_tipo                 0
# Sexo                        0
# Edad                    23669
# Conocido_Desconocido        0
# Nombre(s)               14423
# Primer_apellido         14617
# Segundo_apellido        17882
# Institución_origen          0
# Rdoc                        0
# Datos alternativos      38879
# Marca_temporal              0
# dtype: int64
# **************************************************
# Tipos de datos por columna:
# ID                       object
# Nombre_completo          object
# Estado_origen            object
# Municipio_origen         object
# Panteón_origen           object
# Estatus_FC               object
# Fecha_inhumación         object
# Fecha_defunción          object
# Restos_tipo              object
# Sexo                     object
# Edad                     object
# Conocido_Desconocido     object
# Nombre(s)                object
# Primer_apellido          object
# Segundo_apellido         object
# Institución_origen       object
# Rdoc                     object
# Datos alternativos      float64
# Marca_temporal           object
# dtype: object

# %%
df_actual = df.copy()

# %% [markdown]
# ## **Limpieza de datos**

# %%
# Se filtran las filas de personas repetidas las cuales tienen '_' en su ID
df_actual = df[~df['ID'].str.contains('_')]

# %%
# Se le asigna 'Desconocido' a los valores vacíos y nulos de la columna 'Nombre_completo'
df_actual['Nombre_completo'] = df_actual['Nombre_completo'].replace('  ','Desconocido')
df_actual['Nombre_completo'] = df_actual['Nombre_completo'].fillna('Desconocido')
# Out:
# <ipython-input-114-e2e1ea918105>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_actual['Nombre_completo'] = df_actual['Nombre_completo'].replace('  ','Desconocido')
# <ipython-input-114-e2e1ea918105>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_actual['Nombre_completo'] = df_actual['Nombre_completo'].fillna('Desconocido')

# %%
# Convierte la columna "Fecha_inhumación" a tipo de dato "datetime"
df_actual['Fecha_inhumación'] = pd.to_datetime(df_actual['Fecha_inhumación'], format='%d/%m/%Y', errors='coerce')
# Out:
# <ipython-input-115-7a64538ff2bd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_actual['Fecha_inhumación'] = pd.to_datetime(df_actual['Fecha_inhumación'], format='%d/%m/%Y', errors='coerce')

# %%
# Convierte la columna "Fecha_defunción" a tipo de dato "datetime"
df_actual['Fecha_defunción'] = pd.to_datetime(df_actual['Fecha_defunción'], format='%d/%m/%Y', errors='coerce')
# Out:
# <ipython-input-116-8d1e27b8ed75>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_actual['Fecha_defunción'] = pd.to_datetime(df_actual['Fecha_defunción'], format='%d/%m/%Y', errors='coerce')

# %%
# Convierte la columna "Marca temporal" a tipo de dato "datetime"
df_actual['Marca_temporal'] = pd.to_datetime(df_actual['Marca_temporal'], format='%d/%m/%Y', errors='coerce')
# Out:
# <ipython-input-117-eda4be694e3b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_actual['Marca_temporal'] = pd.to_datetime(df_actual['Marca_temporal'], format='%d/%m/%Y', errors='coerce')

# %%
# Se cambian el domininio de los valores de la columna 'Conocido_Desconocido'
# Asignando 1 si el valor es 'Conocido' y 0 si es 'Desconocido'
df_actual['Conocido_Desconocido'] = df_actual['Conocido_Desconocido'].replace({'Desconocido': 0, 'Conocido': 1})
# Out:
# <ipython-input-118-003f62262ec1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_actual['Conocido_Desconocido'] = df_actual['Conocido_Desconocido'].replace({'Desconocido': 0, 'Conocido': 1})

# %%
# Función para manejar los valores de la columna 'Edad' que no estan en años
def edades_cero(edad):
    try:
        # Intentamos convertir el valor a entero
        return int(edad)
    except:
        # Si el valor es NaN o S/D, lo dejamos como está
        if pd.isna(edad) or edad == 'S/D':
            return edad
        # Si no se puede convertir y no es NaN ni S/D, lo convertimos a 0
        return 0

# Aplicamos la función a la columna 'Edad'
df_actual['Edad'] = df_actual['Edad'].apply(edades_cero)
# Out:
# <ipython-input-120-8aa5474ca513>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_actual['Edad'] = df_actual['Edad'].apply(edades_cero)

# %%
# Convertirmos el tipo de dato de la columna 'Edad' a numerico
df_actual['Edad'] = pd.to_numeric(df_actual['Edad'], errors='coerce')
# Out:
# <ipython-input-121-24203562be06>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_actual['Edad'] = pd.to_numeric(df_actual['Edad'], errors='coerce')

# %%
# Asignamos a los valores NaN el valor de la media de las demás edades
media_edad = df_actual['Edad'].mean()
df_actual['Edad'].fillna(media_edad, inplace=True)
# Out:
# <ipython-input-122-9dd3a821d192>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_actual['Edad'].fillna(media_edad, inplace=True)

# %%
# Convertimos a entero la columna de 'Edad'
df_actual['Edad'] = df_actual['Edad'].astype(int)
# Out:
# <ipython-input-123-676727aa2cf1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_actual['Edad'] = df_actual['Edad'].astype(int)

# %%
# Elimina la columna "Datos_alternativos", "Rdoc", "Nombre(s)", "Primer_apellido" y "Segundo_apellido".
df_actual = df_actual.drop(columns=["Datos alternativos", "Rdoc", "Nombre(s)", "Primer_apellido", "Segundo_apellido"], axis=1)

# %%
df_actual.head(5)
# Out:
#         ID      Nombre_completo     Estado_origen Municipio_origen  \
# 0  XX-P001          Desconocido  Ciudad de México   Miguel Hidalgo
# 1  XX-P002          Desconocido  Ciudad de México   Miguel Hidalgo
# 2  XX-P003  Alberto Cruz Lucero  Ciudad de México   Miguel Hidalgo
# 3  XX-P004          Desconocido  Ciudad de México   Miguel Hidalgo
# 4  XX-P005          Desconocido  Ciudad de México   Miguel Hidalgo
#
#              Panteón_origen  Estatus_FC Fecha_inhumación Fecha_defunción  \
# 0  Panteón Civil de Dolores  Inhumación       2019-01-30      2018-03-04
# 1  Panteón Civil de Dolores  Inhumación       2019-01-26      2018-12-12
# 2  Panteón Civil de Dolores  Inhumación       2019-01-26      2018-12-13
# 3  Panteón Civil de Dolores  Inhumación       2019-01-26      2018-12-14
# 4  Panteón Civil de Dolores  Inhumación       2019-01-26      2018-12-18
#
#        Restos_tipo       Sexo  Edad  Conocido_Desconocido  \
# 0  Restos cremados  Masculino    55                     0
# 1          Cadáver  Masculino    43                     0
# 2          Cadáver  Masculino    43                     1
# 3          Cadáver  Masculino    43                     0
# 4          Cadáver  Masculino    43                     0
#
#                                   Institución_origen Marca_temporal
# 0        UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA     2020-03-23
# 1  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...     2020-03-23
# 2  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...     2020-03-23
# 3  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...     2020-03-23
# 4  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...     2020-03-23

# %%
# Se imprime la lista de los nombres de las columnas del DataFrame
lista_col_actuales=df_actual.columns.tolist()
print(lista_col_actuales)

# Se crea el diccionario con los nuevos nombres de las columnas
mapeo_nombre_columna = {
    'ID': 'id',
    'Nombre_completo': 'nombre_completo',
    'Estado_origen': 'estado_origen',
    'Municipio_origen': 'municipio_origen',
    'Panteón_origen': 'panteon_origen',
    'Estatus_FC': 'estatus',
    'Fecha_inhumación': 'fecha_inhumacion',
    'Fecha_defunción': 'fecha_defuncion',
    'Restos_tipo': 'restos_tipo',
    'Sexo': 'sexo',
    'Edad': 'edad',
    'Conocido_Desconocido': 'conocido',
    'Institución_origen': 'institucion_origen',
    'Marca_temporal': 'marca_temporal',
}
# Out:
# ['ID', 'Nombre_completo', 'Estado_origen', 'Municipio_origen', 'Panteón_origen', 'Estatus_FC', 'Fecha_inhumación', 'Fecha_defunción', 'Restos_tipo', 'Sexo', 'Edad', 'Conocido_Desconocido', 'Institución_origen', 'Marca_temporal']

# %%
# Se renombran las columnas de nuestro dataset
df_actual.rename(columns=mapeo_nombre_columna, inplace=True)

# %%
df_actual.head(2)
# Out:
#         id nombre_completo     estado_origen municipio_origen  \
# 0  XX-P001     Desconocido  Ciudad de México   Miguel Hidalgo
# 1  XX-P002     Desconocido  Ciudad de México   Miguel Hidalgo
#
#              panteon_origen     estatus fecha_inhumacion fecha_defuncion  \
# 0  Panteón Civil de Dolores  Inhumación       2019-01-30      2018-03-04
# 1  Panteón Civil de Dolores  Inhumación       2019-01-26      2018-12-12
#
#        restos_tipo       sexo  edad  conocido  \
# 0  Restos cremados  Masculino    55         0
# 1          Cadáver  Masculino    43         0
#
#                                   institucion_origen marca_temporal
# 0        UNIVERSIDAD WESTHILL - FACULTAD DE MEDICINA     2020-03-23
# 1  INSTITUTO DE CIENCIAS FORENSES - TRIBUNAL SUPE...     2020-03-23

# %%
info_general_df(df_actual)
# Out:
# Información general del DataFrame
#
# Cantidad de filas y columnas: (39987, 14)
# **************************************************
# Cantidad de datos nulos por columna:
# id                        0
# nombre_completo           0
# estado_origen             0
# municipio_origen          0
# panteon_origen            0
# estatus                   0
# fecha_inhumacion       4419
# fecha_defuncion       24304
# restos_tipo               0
# sexo                      0
# edad                      0
# conocido                  0
# institucion_origen        0
# marca_temporal          398
# dtype: int64
# **************************************************
# Tipos de datos por columna:
# id                            object
# nombre_completo               object
# estado_origen                 object
# municipio_origen              object
# panteon_origen                object
# estatus                       object
# fecha_inhumacion      datetime64[ns]
# fecha_defuncion       datetime64[ns]
# restos_tipo                   object
# sexo                          object
# edad                           int64
# conocido                       int64
# institucion_origen            object
# marca_temporal        datetime64[ns]
# dtype: object

# %% [markdown]
# #**Análisis de datos**

# %% [markdown]
# ##Preguntas

# %% [markdown]
# ### a) ¿Cuantás inhumaciones han sido reportadas por cada panteón?

# %%
inhumaciones_por_panteon = df_actual[df_actual["estatus"] == "Inhumación"].groupby("panteon_origen")["estatus"].count()
print(inhumaciones_por_panteon)
# Out:
# panteon_origen
# Cementerio El Progreso                    203
# Panteon Municipal de Teziutlán            156
# Panteon San Nicolás                        70
# Panteón 21 de Marzo                        69
# Panteón Civil de Dolores                18023
# Panteón Héroes Civiles de Guaymas         307
# Panteón Jardín La Cruz                   2687
# Panteón Mezquitán                         184
# Panteón Municipal                          92
# Panteón Municipal Bosques de Xalapa        28
# Panteón Municipal Hidalgo                 136
# Panteón Municipal Mina 40                 142
# Panteón Municipal San Martín              247
# Panteón Municipal Xalisco                   8
# Panteón Municipal de Puebla              1062
# Panteón Municipal de San Miguel Xico      168
# Panteón Municipal de Toluca               154
# Panteón Municipal de Veracruz             501
# Panteón Norte                             108
# Panteón Nuevo Guadalajara                 137
# Panteón Palo Verde                        414
# Panteón Sahuaro                           185
# Panteón San José                          186
# Panteón San José Rio Hondo              11340
# Panteón Seis Jardin                      2819
# Panteón Xalapeño                          126
# Panteón Yañez                               1
# Panteón del Barrio de Chignaulingo          1
# Panteón del Barrio de Fresnillo             1
# Name: estatus, dtype: int64

# %% [markdown]
# ### b) ¿Qué Estados están reportados en el módulo?

# %%
# Funcion para imprimir una lista elemento por elemento
def print_lista(lista):
  for elemento in lista:
    print(elemento)

# %%
estados_reportados = df_actual['estado_origen'].unique()
print('Los estados reportados en el módulo son:')
print_lista(estados_reportados)
# Out:
# Los estados reportados en el módulo son:
# Ciudad de México
# Estado de México
# Sonora
# Puebla
# Veracruz de Ignacio de la Llave
# Jalisco
# Guerrero
# Chiapas
# Nayarit
# Sinaloa
# Oaxaca

# %% [markdown]
# ### c) ¿En qué estados hay más inhumaciones?

# %%
# Se agrupa el número de inhumaciones reportadas por estado
inhumaciones_por_estado = df_actual[df_actual["estatus"] == "Inhumación"].groupby("estado_origen")["estatus"].count()
print(inhumaciones_por_estado)
# Out:
# estado_origen
# Chiapas                               92
# Ciudad de México                   18023
# Estado de México                   12307
# Jalisco                              524
# Nayarit                             2695
# Oaxaca                              2819
# Puebla                              1220
# Sinaloa                               69
# Sonora                               601
# Veracruz de Ignacio de la Llave     1205
# Name: estatus, dtype: int64

# %%
# Se obtiene el número máximo de inhumaciones
num_max_inhumaciones_por_estado = inhumaciones_por_estado.max()

# %%
# Se filtran los estados que tienen el numero máximo de ihumaciones
estados_con_max_inhumaciones = inhumaciones_por_estado[inhumaciones_por_estado == num_max_inhumaciones_por_estado].index.tolist()
print('Los estados con el máximo de inhumaciones son:')
print_lista(estados_con_max_inhumaciones)
# Out:
# Los estados con el máximo de inhumaciones son:
# Ciudad de México

# %% [markdown]
# ### (d) ¿En qué estados hay menos inhumaciones?

# %%
# Se obtiene el número mínimo de inhumaciones
num_min_inhumaciones_por_estado = inhumaciones_por_estado.min()

# %%
# Se filtran los estados que tienen el numero mínimo de ihumaciones
estados_con_min_inhumaciones = inhumaciones_por_estado[inhumaciones_por_estado == num_min_inhumaciones_por_estado].index.tolist()
print('Los estados con el mínimo de inhumaciones son:')
print_lista(estados_con_min_inhumaciones)
# Out:
# Los estados con el mínimo de inhumaciones son:
# Sinaloa

# %% [markdown]
# ### (e) ¿Cuántos restos son conocidos y cuántos desconocidos?

# %%
# Contamos el número de restos conocidos (valores 1)
cant_restos_conocidos = df_actual['conocido'].sum()
# Calculamos la cantidad de restos desconocidos
cant_restos_desconocidos = len(df_actual) - cant_restos_conocidos
print(f'Hay {cant_restos_conocidos} restos registrados como conocidos')
print(f'Hay {cant_restos_desconocidos} restos registrados como desconocidos')
# Out:
# Hay 27288 restos registrados como conocidos
# Hay 12699 restos registrados como desconocidos

# %% [markdown]
# ### (f) ¿Cuáles son los tipos de restos registrados en el módulo y cuántos registros hay de cada tipo?

# %%
tipos_de_restos = df_actual.groupby('restos_tipo')['id'].count()
print('Tipos de restos registrados en el módulo y su frecuencia:')
print(tipos_de_restos)
# Out:
# Tipos de restos registrados en el módulo y su frecuencia:
# restos_tipo
# Cadáver            30720
# Feto                2284
# Miembros            2062
# Restos cremados     2750
# Restos humanos       786
# Restos óseos         279
# Sin dato            1106
# Name: id, dtype: int64
